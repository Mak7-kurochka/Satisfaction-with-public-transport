# %%
import functs_for_psychology as ffp

# %%
ffp.create_pie('Jak często Pan/Pani stoi w korkach? ')

# %%
 ffp.df['Do jakiej dzielnicy Pan/Pani jeździ najczęściej?'].value_counts() , ffp.create_bar( 'Do jakiej dzielnicy Pan/Pani jeździ najczęściej?'), ffp.create_pie('Do jakiej dzielnicy Pan/Pani jeździ najczęściej?')
# Out:
# (None, None)

# %%
ffp.create_pie('Z jakiego rodzaju transportu publicznego Pan/Pani korzysta najczęściej?')

# %%
ffp.create_pie( 'Ile przesiadek  Pan/Pani robi podczas podróży?')

# %%
ffp.create_pie('Do jakiego rodzaju transportu Pan/Pani przesiada najcięściej?')

# %%
ffp.create_pie('Z jakich alternatyw transportu publicznego Pan/Pani korzysta, kiedy nie może skorzystać komunikacją miejską?')
