# %%
import functs_for_psychology as ffp

# %%
ffp.create_pie('Czy korzysta Pan/Pani mobilnymi dodatkami dla śledzenia rozkładu jazdy komunikacji miejskiej?')

# %%
ffp.create_pie('Czy zawsze transport przybywa zgodnie z rozkładem?')

# %%
ffp.create_pie('Jeżeli nie, to na ile w średnim spóźnia się?')

# %%
ffp.create_pie('Czy kiedykolwiek Pan/Pani musiał/-a czekać na transport publiczny który nigdy nie przyjechał?')
