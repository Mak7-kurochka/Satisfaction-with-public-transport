# %%
import functs_for_psychology as ffp

# %%
ffp.create_pie('Czy Pan/Pani korzysta biletem miesięcznym?')

# %%
ffp.create_pie( 'Czy Pan/Pani popiera inicjatywy dające pierwszeństwo transportowi publicznemu przed samochodem osobowym? (Zwężenie dróg, ulice tramwajowo-piesze itp.)')

# %%
ffp.create_pie('Jak efektywny jest transport hulajnóg i rowerów w mieście?')

# %%
ffp.create_pie('Czy infrastruktura hulajnog i rowerowa wymaga rozbudowy?')

# %%
ffp.create_pie('Gdyby od jutra transport publiczny był bezpłatny, Pan/Pani zacząłby z niego częściej korzystać?')
