# %%
import pandas as pd
from matplotlib import pyplot as plt
from collections import Counter
import functs_for_psychology as ffp
plt.style.use('fivethirtyeight')

# %%
df = pd.read_csv('Zadowolenie z komunikacji miejskiej mieszkańców Krakowa (Responses).csv')
df.drop(columns=['Timestamp', 'Email Address'], inplace=True)

# %%
ffp.create_pie('Ile Pan/Pani ma lat?')

# %%
ffp.create_pie('Kim Pan/Pani jest?')

# %%
ffp.create_pie('Jak długo Pan/Pani mieszka w Krakowie?')

# %%
ffp.create_pie('Czy korzysta Pan/Pani komunikacją miejską?')

# %%
for_bar = pd.DataFrame(df['Jak Pan/Pani jest zadowolony z komunikacji miejskiej?'].value_counts())
name_f_b = list(for_bar.index)
numb = list(for_bar['Jak Pan/Pani jest zadowolony z komunikacji miejskiej?'])

plt.bar(name_f_b, numb)

plt.tight_layout()

plt.title('Jak Pan/Pani jest zadowolony z komunikacji miejskiej?')
# Out:
# Text(0.5, 1.0, 'Jak Pan/Pani jest zadowolony z komunikacji miejskiej?')
