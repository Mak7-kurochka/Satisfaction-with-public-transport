# %%
import pandas as pd
from matplotlib import pyplot as plt
from collections import Counter
plt.style.use('fivethirtyeight')

# %%
na_vals = [ 'NA', 'Missing' ]
df = pd.read_csv('Zadowolenie z komunikacji miejskiej mieszkańców Krakowa (Responses).csv', na_values=na_vals)

# %%
df.drop(columns=['Timestamp', 'Email Address'], inplace=True)

# %%
df.columns
# Out:
# Index(['Ile Pan/Pani ma lat?', 'Kim Pan/Pani jest?',
#        'Jak długo Pan/Pani mieszka w Krakowie?',
#        'Czy korzysta Pan/Pani komunikacją miejską?',
#        'Z jakiego rodzaju transportu publicznego Pan/Pani korzysta najczęściej?',
#        'Jak często Pan/Pani korzysta transportu publicznego?',
#        'Ile czasu dziennie Pan/Pani spędza podróżując transportem? ',
#        'Do jakiej dzielnicy Pan/Pani jeździ najczęściej?',
#        'Dokąd Pan/Pani jeździ transportem?',
#        'Ile przesiadek  Pan/Pani robi podczas podróży?',
#        'Do jakiego rodzaju transportu Pan/Pani przesiada najcięściej?',
#        'Jak często Pan/Pani stoi w korkach? ',
#        'Z jakich alternatyw transportu publicznego Pan/Pani korzysta, kiedy nie może skorzystać komunikacją miejską?',
#        'Co dla Pana/Pani jest ważniejsze podczas podróży?',
#        'Czy korzysta Pan/Pani mobilnymi dodatkami dla śledzenia rozkładu jazdy komunikacji miejskiej?',
#        'Czy zawsze transport przybywa zgodnie z rozkładem?',
#        'Jeżeli nie, to na ile w średnim spóźnia się?',
#        'Czy kiedykolwiek Pan/Pani musiał/-a czekać na transport publiczny który nigdy nie przyjechał?',
#        'Jeżeli tak, to co Pan/Pani robił/-a w takim wypadku?',
#        'Czy Pan/Pani korzysta biletem miesięcznym?',
#        'Czy Pan/Pani popiera inicjatywy dające pierwszeństwo transportowi publicznemu przed samochodem osobowym? (Zwężenie dróg, ulice tramwajowo-piesze itp.)',
#        'Jak efektywny jest transport hulajnóg i rowerów w mieście?',
#        'Czy infrastruktura hulajnog i rowerowa wymaga rozbudowy?',
#        'Gdyby od jutra transport publiczny był bezpłatny, Pan/Pani zacząłby z niego częściej korzystać?',
#        'Jak Pan/Pani jest zadowolony z komunikacji miejskiej?'],
#       dtype='object')

# %%
df.head()
# Out:
#   Ile Pan/Pani ma lat? Kim Pan/Pani jest?  \
# 0                18-26              Panem
# 1                18-26              Panem
# 2                18-26           Nie wiem
# 3                  <18              Panem
# 4                  <18              Panią
#
#   Jak długo Pan/Pani mieszka w Krakowie?  \
# 0                               < 1 roku
# 1                              1 - 5 łat
# 2                              1 - 5 łat
# 3                              1 - 5 łat
# 4                              1 - 5 łat
#
#   Czy korzysta Pan/Pani komunikacją miejską?  \
# 0                                        Tak
# 1                                        Tak
# 2                                        Tak
# 3                                        Tak
# 4                                        Tak
#
#   Z jakiego rodzaju transportu publicznego Pan/Pani korzysta najczęściej?  \
# 0                                            Autobus
# 1                                            Autobus
# 2                                            Autobus
# 3                                            Autobus
# 4                                            Autobus
#
#   Jak często Pan/Pani korzysta transportu publicznego?  \
# 0                          Więcej niż 4 razy w dzień
# 1                                   2-4 razy w dzień
# 2                                   2-4 razy w dzień
# 3                                   2-4 razy w dzień
# 4                                     2 razy w dzień
#
#   Ile czasu dziennie Pan/Pani spędza podróżując transportem?   \
# 0                                          Do 30 min
# 1                                      Około godziny
# 2                                          Do 30 min
# 3                                      Około godziny
# 4                                          Do 30 min
#
#   Do jakiej dzielnicy Pan/Pani jeździ najczęściej?  \
# 0                                       Krowodrza
# 1                                     Stare Miasto
# 2                                     Stare Miasto
# 3                                     Stare Miasto
# 4                                     Stare Miasto
#
#   Dokąd Pan/Pani jeździ transportem?  \
# 0                         Do uczelni
# 1                         Do uczelni
# 2                         Do uczelni
# 3                         Do uczelni
# 4                         Do uczelni
#
#   Ile przesiadek  Pan/Pani robi podczas podróży?  ...  \
# 0                                              0  ...
# 1                                              0  ...
# 2                                              0  ...
# 3                                              0  ...
# 4                                              0  ...
#
#   Czy zawsze transport przybywa zgodnie z rozkładem?  \
# 0                                                Tak
# 1                                                Tak
# 2                                                Nie
# 3                                                Nie
# 4                                                Nie
#
#   Jeżeli nie, to na ile w średnim spóźnia się?  \
# 0                              Nie spóźnia się
# 1                              Nie spóźnia się
# 2                                      < 5 min
# 3                                      < 5 min
# 4                                      < 5 min
#
#   Czy kiedykolwiek Pan/Pani musiał/-a czekać na transport publiczny który nigdy nie przyjechał?  \
# 0                                                Nie
# 1                                                Tak
# 2                                                Tak
# 3                                                Tak
# 4                                                Tak
#
#   Jeżeli tak, to co Pan/Pani robił/-a w takim wypadku?  \
# 0                                                NaN
# 1                                                NaN
# 2                                            Czekam
# 3                                    Proszę napisać:
# 4                                    Krzyczę:"kurwa"
#
#   Czy Pan/Pani korzysta biletem miesięcznym?  \
# 0                                        Nie
# 1                                        Tak
# 2                                        Tak
# 3                                        Tak
# 4                                        Tak
#
#   Czy Pan/Pani popiera inicjatywy dające pierwszeństwo transportowi publicznemu przed samochodem osobowym? (Zwężenie dróg, ulice tramwajowo-piesze itp.)  \
# 0                                                Tak
# 1                                                Nie
# 2                                                Tak
# 3                                                Tak
# 4                                                Nie
#
#   Jak efektywny jest transport hulajnóg i rowerów w mieście?  \
# 0                                          Efektywny
# 1                                          Efektywny
# 2                                          Efektywny
# 3                                          Efektywny
# 4                                          Efektywny
#
#   Czy infrastruktura hulajnog i rowerowa wymaga rozbudowy?  \
# 0                                                Tak
# 1                                                Tak
# 2                                                Nie
# 3                                                Tak
# 4                                                Tak
#
#   Gdyby od jutra transport publiczny był bezpłatny, Pan/Pani zacząłby z niego częściej korzystać?  \
# 0                                                Tak
# 1                       Nie. Używam go bardzo często
# 2                                                Tak
# 3                       Nie. Używam go bardzo często
# 4                       Nie. Używam go bardzo często
#
#   Jak Pan/Pani jest zadowolony z komunikacji miejskiej?
# 0                                                  8
# 1                                                  8
# 2                                                  8
# 3                                                  8
# 4                                                  7
#
# [5 rows x 25 columns]

# %%
def create_pie(name_file):
    fstdf = pd.DataFrame(df[name_file].value_counts('normal'))
    age = list(fstdf.index)

    count = []
    for i in range(fstdf[name_file].count()):
        count.append(fstdf[name_file][i])
    for i in range(len(count)): count[i] *= 100

    inp = input('Maybe you want add a title for legend table?: ')
    if inp == 'Yes' or inp == 'yes':
        name_table = input('Enter a title: ')
        plt.pie(count,
            autopct = '%1.1f%%', pctdistance=1.15)

        plt.legend(age, loc='center right', title=name_table, 
                   bbox_to_anchor=(1, 0, 0.5, 0), fontsize='12')

        plt.title(name_file)
    else:
        plt.pie(count,
            autopct = '%1.1f%%', pctdistance=1.15)

        plt.legend(age, loc='center right', bbox_to_anchor=(1, 0, 0.5, 0), fontsize='12')

        plt.title(name_file)

# %%
create_pie('Ile Pan/Pani ma lat?')

# %%
create_pie('Kim Pan/Pani jest?')

# %%
create_pie('Jak długo Pan/Pani mieszka w Krakowie?')

# %%
create_pie('Czy korzysta Pan/Pani komunikacją miejską?')

# %%
create_pie('Z jakiego rodzaju transportu publicznego Pan/Pani korzysta najczęściej?')

# %%
create_pie('Jak często Pan/Pani korzysta transportu publicznego?')

# %%
create_pie('Ile czasu dziennie Pan/Pani spędza podróżując transportem? ')

# %%
df['Do jakiej dzielnicy Pan/Pani jeździ najczęściej?'] = df['Do jakiej dzielnicy Pan/Pani jeździ najczęściej?'].str.replace('Berlin', 'Stare Miasto')
create_pie('Do jakiej dzielnicy Pan/Pani jeździ najczęściej?')

# %%
df['Dokąd Pan/Pani jeździ transportem?'] = df['Dokąd Pan/Pani jeździ transportem?'].str.replace('Na Berlin', 'Na spacer') 
df['Dokąd Pan/Pani jeździ transportem?'] = df['Dokąd Pan/Pani jeździ transportem?'].str.replace('Blyadki', 'Na spacer')
df['Dokąd Pan/Pani jeździ transportem?'] = df['Dokąd Pan/Pani jeździ transportem?'].str.replace('spacerować', 'Na spacer')
place_counter = Counter()

for response in df['Dokąd Pan/Pani jeździ transportem?']:
    place_counter.update(response.split(','))
places = []
popularity = []

for item in place_counter.most_common(15):
    places.append(item[0])
    popularity.append(item[1])
places, popularity

plt.barh(places, popularity)
plt.gca().invert_yaxis()

# %%
tnthdf = pd.DataFrame(df['Ile przesiadek  Pan/Pani robi podczas podróży?'].value_counts())
num_of_trans = list(tnthdf.index)
