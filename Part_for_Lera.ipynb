# %%
import functs_for_psychology as ffp

# %%
ffp.create_pie('Jak często Pan/Pani korzysta transportu publicznego?')

# %%
ffp.create_pie('Ile czasu dziennie Pan/Pani spędza podróżując transportem? ')

# %%
ffp.create_bar('Dokąd Pan/Pani jeździ transportem?', 'h'), ffp.df['Dokąd Pan/Pani jeździ transportem?'].value_counts()
# Out:
# (None,
#  Do uczelni                            167
#  Do pracy                              111
#  Na zakupy                              35
#  Do uczelni,Do pracy                    22
#  Do pracy,Na zakupy                     13
#  Do uczelni,Na zakupy                   11
#  Do uczelni,Do pracy,Na zakupy           7
#  Inne                                    7
#  Na zakupy,Inne                          6
#  Do pracy,Na zakupy,Inne                 4
#  Do uczelni,Na zakupy,Inne               3
#  Do uczelni,Inne                         3
#  Do uczelni,Do pracy,Na zakupy,Inne      2
#  Do pracy,Inne                           2
#  Do pracy,Na zakupy,Na spacer            2
#  Do rodziny                              2
#  Do uczelni,Do żony                      1
#  Po sprawach                             1
#  Na zakupy,Na spacer                     1
#  Do uczelni,Na spacer                    1
#  Do żony                                 1
#  Inne,Do rodziny                         1
# ...

# %%
ffp.create_pie('Co dla Pana/Pani jest ważniejsze podczas podróży?')
